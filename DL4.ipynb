# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks

# %%
# reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
# 1) Create synthetic imbalanced dataset (1% anomalies)
X, y_raw = make_classification(n_samples=10000, n_features=20, n_informative=15,
                               n_redundant=5, weights=[0.01, 0.99],
                               flip_y=0, random_state=RANDOM_SEED)

# %%
# Map labels so: 1 = normal, 0 = anomaly (matches your lab note)
y = y_raw.copy()

# %%
# 2) Train/test split
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.25,
                                                              stratify=y, random_state=RANDOM_SEED)

# %%
# Train autoencoder only on normal samples:
X_train = X_train_full[y_train_full == 1]

# %%
# 3) Scale (fit scaler on normal train)
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# 4) Build autoencoder
input_dim = X_train_scaled.shape[1]
encoding_dim = 8

# %%
inputs = keras.Input(shape=(input_dim,))
x = layers.Dense(64, activation="relu")(inputs)
x = layers.Dense(32, activation="relu")(x)
encoded = layers.Dense(encoding_dim, activation="relu", name="latent")(x)

# %%
x = layers.Dense(32, activation="relu")(encoded)
x = layers.Dense(64, activation="relu")(x)
outputs = layers.Dense(input_dim, activation="linear")(x)

# %%
autoencoder = keras.Model(inputs, outputs, name="autoencoder")
autoencoder.compile(optimizer=keras.optimizers.Adam(1e-3), loss="mse", metrics=["mse"])

# %%
# 5) Train (with early stopping)
es = callbacks.EarlyStopping(monitor="val_loss", patience=6, restore_best_weights=True)
history = autoencoder.fit(X_train_scaled, X_train_scaled,
                          epochs=100, batch_size=64, validation_split=0.1,
                          callbacks=[es], verbose=2)
# Out:
# Epoch 1/100
# 105/105 - 1s - 13ms/step - loss: 0.7615 - mse: 0.7615 - val_loss: 0.5070 - val_mse: 0.5070
# Epoch 2/100
# 105/105 - 0s - 2ms/step - loss: 0.3852 - mse: 0.3852 - val_loss: 0.3140 - val_mse: 0.3140
# Epoch 3/100
# 105/105 - 0s - 2ms/step - loss: 0.2645 - mse: 0.2645 - val_loss: 0.2408 - val_mse: 0.2408
# Epoch 4/100
# 105/105 - 0s - 2ms/step - loss: 0.2124 - mse: 0.2124 - val_loss: 0.2064 - val_mse: 0.2064
# Epoch 5/100
# 105/105 - 0s - 2ms/step - loss: 0.1882 - mse: 0.1882 - val_loss: 0.1869 - val_mse: 0.1869
# Epoch 6/100
# 105/105 - 0s - 2ms/step - loss: 0.1738 - mse: 0.1738 - val_loss: 0.1727 - val_mse: 0.1727
# Epoch 7/100
# 105/105 - 0s - 2ms/step - loss: 0.1631 - mse: 0.1631 - val_loss: 0.1616 - val_mse: 0.1616
# Epoch 8/100
# 105/105 - 0s - 2ms/step - loss: 0.1543 - mse: 0.1543 - val_loss: 0.1529 - val_mse: 0.1529
# Epoch 9/100
# 105/105 - 0s - 2ms/step - loss: 0.1477 - mse: 0.1477 - val_loss: 0.1463 - val_mse: 0.1463
# Epoch 10/100
# 105/105 - 0s - 2ms/step - loss: 0.1426 - mse: 0.1426 - val_loss: 0.1412 - val_mse: 0.1412
# Epoch 11/100
# 105/105 - 0s - 2ms/step - loss: 0.1384 - mse: 0.1384 - val_loss: 0.1365 - val_mse: 0.1365
# Epoch 12/100
# 105/105 - 0s - 2ms/step - loss: 0.1349 - mse: 0.1349 - val_loss: 0.1324 - val_mse: 0.1324
# Epoch 13/100
# 105/105 - 0s - 2ms/step - loss: 0.1320 - mse: 0.1320 - val_loss: 0.1291 - val_mse: 0.1291
# Epoch 14/100
# 105/105 - 0s - 2ms/step - loss: 0.1294 - mse: 0.1294 - val_loss: 0.1265 - val_mse: 0.1265
# Epoch 15/100
# 105/105 - 0s - 2ms/step - loss: 0.1271 - mse: 0.1271 - val_loss: 0.1243 - val_mse: 0.1243
# Epoch 16/100
# 105/105 - 0s - 2ms/step - loss: 0.1251 - mse: 0.1251 - val_loss: 0.1223 - val_mse: 0.1223
# Epoch 17/100
# 105/105 - 0s - 2ms/step - loss: 0.1233 - mse: 0.1233 - val_loss: 0.1204 - val_mse: 0.1204
# Epoch 18/100
# 105/105 - 0s - 2ms/step - loss: 0.1218 - mse: 0.1218 - val_loss: 0.1189 - val_mse: 0.1189
# Epoch 19/100
# 105/105 - 0s - 2ms/step - loss: 0.1203 - mse: 0.1203 - val_loss: 0.1174 - val_mse: 0.1174
# Epoch 20/100
# 105/105 - 0s - 2ms/step - loss: 0.1190 - mse: 0.1190 - val_loss: 0.1161 - val_mse: 0.1161
# Epoch 21/100
# 105/105 - 0s - 2ms/step - loss: 0.1177 - mse: 0.1177 - val_loss: 0.1149 - val_mse: 0.1149
# Epoch 22/100
# 105/105 - 0s - 2ms/step - loss: 0.1165 - mse: 0.1165 - val_loss: 0.1139 - val_mse: 0.1139
# Epoch 23/100
# 105/105 - 0s - 2ms/step - loss: 0.1153 - mse: 0.1153 - val_loss: 0.1129 - val_mse: 0.1129
# Epoch 24/100
# 105/105 - 0s - 2ms/step - loss: 0.1142 - mse: 0.1142 - val_loss: 0.1121 - val_mse: 0.1121
# Epoch 25/100
# 105/105 - 0s - 2ms/step - loss: 0.1132 - mse: 0.1132 - val_loss: 0.1113 - val_mse: 0.1113
# Epoch 26/100
# 105/105 - 0s - 2ms/step - loss: 0.1123 - mse: 0.1123 - val_loss: 0.1102 - val_mse: 0.1102
# Epoch 27/100
# 105/105 - 0s - 2ms/step - loss: 0.1114 - mse: 0.1114 - val_loss: 0.1094 - val_mse: 0.1094
# Epoch 28/100
# 105/105 - 0s - 2ms/step - loss: 0.1105 - mse: 0.1105 - val_loss: 0.1086 - val_mse: 0.1086
# Epoch 29/100
# 105/105 - 0s - 2ms/step - loss: 0.1097 - mse: 0.1097 - val_loss: 0.1079 - val_mse: 0.1079
# Epoch 30/100
# 105/105 - 0s - 2ms/step - loss: 0.1090 - mse: 0.1090 - val_loss: 0.1073 - val_mse: 0.1073
# Epoch 31/100
# 105/105 - 0s - 2ms/step - loss: 0.1082 - mse: 0.1082 - val_loss: 0.1067 - val_mse: 0.1067
# Epoch 32/100
# 105/105 - 0s - 2ms/step - loss: 0.1075 - mse: 0.1075 - val_loss: 0.1063 - val_mse: 0.1063
# Epoch 33/100
# 105/105 - 0s - 2ms/step - loss: 0.1069 - mse: 0.1069 - val_loss: 0.1058 - val_mse: 0.1058
# Epoch 34/100
# 105/105 - 0s - 2ms/step - loss: 0.1063 - mse: 0.1063 - val_loss: 0.1053 - val_mse: 0.1053
# Epoch 35/100
# 105/105 - 0s - 2ms/step - loss: 0.1057 - mse: 0.1057 - val_loss: 0.1048 - val_mse: 0.1048
# Epoch 36/100
# 105/105 - 0s - 2ms/step - loss: 0.1051 - mse: 0.1051 - val_loss: 0.1044 - val_mse: 0.1044
# Epoch 37/100
# 105/105 - 0s - 2ms/step - loss: 0.1046 - mse: 0.1046 - val_loss: 0.1039 - val_mse: 0.1039
# Epoch 38/100
# 105/105 - 0s - 2ms/step - loss: 0.1040 - mse: 0.1040 - val_loss: 0.1034 - val_mse: 0.1034
# Epoch 39/100
# 105/105 - 0s - 2ms/step - loss: 0.1035 - mse: 0.1035 - val_loss: 0.1030 - val_mse: 0.1030
# Epoch 40/100
# 105/105 - 0s - 2ms/step - loss: 0.1030 - mse: 0.1030 - val_loss: 0.1027 - val_mse: 0.1027
# Epoch 41/100
# 105/105 - 0s - 2ms/step - loss: 0.1027 - mse: 0.1027 - val_loss: 0.1023 - val_mse: 0.1023
# Epoch 42/100
# 105/105 - 0s - 2ms/step - loss: 0.1022 - mse: 0.1022 - val_loss: 0.1020 - val_mse: 0.1020
# Epoch 43/100
# 105/105 - 0s - 2ms/step - loss: 0.1019 - mse: 0.1019 - val_loss: 0.1017 - val_mse: 0.1017
# Epoch 44/100
# 105/105 - 0s - 2ms/step - loss: 0.1015 - mse: 0.1015 - val_loss: 0.1015 - val_mse: 0.1015
# Epoch 45/100
# 105/105 - 0s - 2ms/step - loss: 0.1011 - mse: 0.1011 - val_loss: 0.1012 - val_mse: 0.1012
# Epoch 46/100
# 105/105 - 0s - 2ms/step - loss: 0.1008 - mse: 0.1008 - val_loss: 0.1010 - val_mse: 0.1010
# Epoch 47/100
# 105/105 - 0s - 2ms/step - loss: 0.1005 - mse: 0.1005 - val_loss: 0.1008 - val_mse: 0.1008
# Epoch 48/100
# 105/105 - 0s - 2ms/step - loss: 0.1003 - mse: 0.1003 - val_loss: 0.1006 - val_mse: 0.1006
# Epoch 49/100
# 105/105 - 0s - 2ms/step - loss: 0.1000 - mse: 0.1000 - val_loss: 0.1005 - val_mse: 0.1005
# Epoch 50/100
# 105/105 - 0s - 2ms/step - loss: 0.0997 - mse: 0.0997 - val_loss: 0.1003 - val_mse: 0.1003
# Epoch 51/100
# 105/105 - 0s - 2ms/step - loss: 0.0993 - mse: 0.0993 - val_loss: 0.1001 - val_mse: 0.1001
# Epoch 52/100
# 105/105 - 0s - 2ms/step - loss: 0.0990 - mse: 0.0990 - val_loss: 0.0998 - val_mse: 0.0998
# Epoch 53/100
# 105/105 - 0s - 2ms/step - loss: 0.0987 - mse: 0.0987 - val_loss: 0.0996 - val_mse: 0.0996
# Epoch 54/100
# 105/105 - 0s - 2ms/step - loss: 0.0984 - mse: 0.0984 - val_loss: 0.0994 - val_mse: 0.0994
# Epoch 55/100
# 105/105 - 0s - 2ms/step - loss: 0.0982 - mse: 0.0982 - val_loss: 0.0994 - val_mse: 0.0994
# Epoch 56/100
# 105/105 - 0s - 2ms/step - loss: 0.0980 - mse: 0.0980 - val_loss: 0.0992 - val_mse: 0.0992
# Epoch 57/100
# 105/105 - 0s - 2ms/step - loss: 0.0978 - mse: 0.0978 - val_loss: 0.0990 - val_mse: 0.0990
# Epoch 58/100
# 105/105 - 0s - 2ms/step - loss: 0.0976 - mse: 0.0976 - val_loss: 0.0989 - val_mse: 0.0989
# Epoch 59/100
# 105/105 - 0s - 2ms/step - loss: 0.0974 - mse: 0.0974 - val_loss: 0.0989 - val_mse: 0.0989
# Epoch 60/100
# 105/105 - 0s - 2ms/step - loss: 0.0972 - mse: 0.0972 - val_loss: 0.0986 - val_mse: 0.0986
# Epoch 61/100
# 105/105 - 0s - 2ms/step - loss: 0.0971 - mse: 0.0971 - val_loss: 0.0985 - val_mse: 0.0985
# Epoch 62/100
# 105/105 - 0s - 2ms/step - loss: 0.0970 - mse: 0.0970 - val_loss: 0.0984 - val_mse: 0.0984
# Epoch 63/100
# 105/105 - 0s - 2ms/step - loss: 0.0968 - mse: 0.0968 - val_loss: 0.0982 - val_mse: 0.0982
# Epoch 64/100
# 105/105 - 0s - 2ms/step - loss: 0.0966 - mse: 0.0966 - val_loss: 0.0981 - val_mse: 0.0981
# Epoch 65/100
# 105/105 - 0s - 2ms/step - loss: 0.0964 - mse: 0.0964 - val_loss: 0.0980 - val_mse: 0.0980
# Epoch 66/100
# 105/105 - 0s - 2ms/step - loss: 0.0963 - mse: 0.0963 - val_loss: 0.0978 - val_mse: 0.0978
# Epoch 67/100
# 105/105 - 0s - 2ms/step - loss: 0.0961 - mse: 0.0961 - val_loss: 0.0977 - val_mse: 0.0977
# Epoch 68/100
# 105/105 - 0s - 2ms/step - loss: 0.0960 - mse: 0.0960 - val_loss: 0.0975 - val_mse: 0.0975
# Epoch 69/100
# 105/105 - 0s - 2ms/step - loss: 0.0959 - mse: 0.0959 - val_loss: 0.0974 - val_mse: 0.0974
# Epoch 70/100
# 105/105 - 0s - 2ms/step - loss: 0.0957 - mse: 0.0957 - val_loss: 0.0973 - val_mse: 0.0973
# Epoch 71/100
# 105/105 - 0s - 2ms/step - loss: 0.0957 - mse: 0.0957 - val_loss: 0.0974 - val_mse: 0.0974
# Epoch 72/100
# 105/105 - 0s - 2ms/step - loss: 0.0955 - mse: 0.0955 - val_loss: 0.0971 - val_mse: 0.0971
# Epoch 73/100
# 105/105 - 0s - 2ms/step - loss: 0.0955 - mse: 0.0955 - val_loss: 0.0972 - val_mse: 0.0972
# Epoch 74/100
# 105/105 - 0s - 2ms/step - loss: 0.0953 - mse: 0.0953 - val_loss: 0.0972 - val_mse: 0.0972
# Epoch 75/100
# 105/105 - 0s - 2ms/step - loss: 0.0952 - mse: 0.0952 - val_loss: 0.0971 - val_mse: 0.0971
# Epoch 76/100
# 105/105 - 0s - 2ms/step - loss: 0.0951 - mse: 0.0951 - val_loss: 0.0971 - val_mse: 0.0971
# Epoch 77/100
# 105/105 - 0s - 2ms/step - loss: 0.0951 - mse: 0.0951 - val_loss: 0.0970 - val_mse: 0.0970
# Epoch 78/100
# 105/105 - 0s - 2ms/step - loss: 0.0950 - mse: 0.0950 - val_loss: 0.0969 - val_mse: 0.0969
# Epoch 79/100
# 105/105 - 0s - 2ms/step - loss: 0.0949 - mse: 0.0949 - val_loss: 0.0969 - val_mse: 0.0969
# Epoch 80/100
# 105/105 - 0s - 2ms/step - loss: 0.0948 - mse: 0.0948 - val_loss: 0.0970 - val_mse: 0.0970
# Epoch 81/100
# 105/105 - 0s - 2ms/step - loss: 0.0947 - mse: 0.0947 - val_loss: 0.0970 - val_mse: 0.0970
# Epoch 82/100
# 105/105 - 0s - 2ms/step - loss: 0.0946 - mse: 0.0946 - val_loss: 0.0969 - val_mse: 0.0969
# Epoch 83/100
# 105/105 - 0s - 2ms/step - loss: 0.0945 - mse: 0.0945 - val_loss: 0.0968 - val_mse: 0.0968
# Epoch 84/100
# 105/105 - 0s - 2ms/step - loss: 0.0944 - mse: 0.0944 - val_loss: 0.0968 - val_mse: 0.0968
# Epoch 85/100
# 105/105 - 0s - 2ms/step - loss: 0.0943 - mse: 0.0943 - val_loss: 0.0971 - val_mse: 0.0971
# Epoch 86/100
# 105/105 - 0s - 2ms/step - loss: 0.0942 - mse: 0.0942 - val_loss: 0.0968 - val_mse: 0.0968
# Epoch 87/100
# 105/105 - 0s - 2ms/step - loss: 0.0941 - mse: 0.0941 - val_loss: 0.0967 - val_mse: 0.0967
# Epoch 88/100
# 105/105 - 0s - 2ms/step - loss: 0.0941 - mse: 0.0941 - val_loss: 0.0966 - val_mse: 0.0966
# Epoch 89/100
# 105/105 - 0s - 2ms/step - loss: 0.0940 - mse: 0.0940 - val_loss: 0.0965 - val_mse: 0.0965
# Epoch 90/100
# 105/105 - 0s - 2ms/step - loss: 0.0939 - mse: 0.0939 - val_loss: 0.0967 - val_mse: 0.0967
# Epoch 91/100
# 105/105 - 0s - 2ms/step - loss: 0.0938 - mse: 0.0938 - val_loss: 0.0964 - val_mse: 0.0964
# Epoch 92/100
# 105/105 - 0s - 2ms/step - loss: 0.0938 - mse: 0.0938 - val_loss: 0.0963 - val_mse: 0.0963
# Epoch 93/100
# 105/105 - 0s - 2ms/step - loss: 0.0937 - mse: 0.0937 - val_loss: 0.0963 - val_mse: 0.0963
# Epoch 94/100
# 105/105 - 0s - 2ms/step - loss: 0.0937 - mse: 0.0937 - val_loss: 0.0961 - val_mse: 0.0961
# Epoch 95/100
# 105/105 - 0s - 2ms/step - loss: 0.0937 - mse: 0.0937 - val_loss: 0.0962 - val_mse: 0.0962
# Epoch 96/100
# 105/105 - 0s - 2ms/step - loss: 0.0936 - mse: 0.0936 - val_loss: 0.0961 - val_mse: 0.0961
# Epoch 97/100
# 105/105 - 0s - 2ms/step - loss: 0.0935 - mse: 0.0935 - val_loss: 0.0962 - val_mse: 0.0962
# Epoch 98/100
# 105/105 - 0s - 2ms/step - loss: 0.0934 - mse: 0.0934 - val_loss: 0.0960 - val_mse: 0.0960
# Epoch 99/100
# 105/105 - 0s - 2ms/step - loss: 0.0934 - mse: 0.0934 - val_loss: 0.0961 - val_mse: 0.0961
# Epoch 100/100
# 105/105 - 0s - 2ms/step - loss: 0.0933 - mse: 0.0933 - val_loss: 0.0959 - val_mse: 0.0959

# %%
# 6) Reconstruction error
recon_train = autoencoder.predict(X_train_scaled)
mse_train = np.mean(np.square(recon_train - X_train_scaled), axis=1)
# Out:
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step

# %%
recon_test = autoencoder.predict(X_test_scaled)
mse_test = np.mean(np.square(recon_test - X_test_scaled), axis=1)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step

# %%
# 7) Threshold selection (two common ways)
threshold_mean_std = mse_train.mean() + 3 * mse_train.std()
threshold_95 = np.percentile(mse_train, 95)
threshold = threshold_95  # choose one to use

# %%
# 8) Predictions: predict anomaly if reconstruction error > threshold
y_pred = np.where(mse_test > threshold, 0, 1)

# %%
# 9) Evaluation
print("Confusion matrix (true 0/1 rows, pred 0/1 cols):")
print(confusion_matrix(y_test, y_pred, labels=[0,1]))
print("\nClassification report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Confusion matrix (true 0/1 rows, pred 0/1 cols):
# [[  19    6]
#  [ 173 2302]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.0990    0.7600    0.1751        25
#            1     0.9974    0.9301    0.9626      2475
#
#     accuracy                         0.9284      2500
#    macro avg     0.5482    0.8451    0.5688      2500
# weighted avg     0.9884    0.9284    0.9547      2500

# %%
# AUC (use recon error as score for anomaly)
y_test_anom = (y_test == 0).astype(int)  # 1 for anomaly
auc = roc_auc_score(y_test_anom, mse_test)
print(f"ROC AUC = {auc:.4f}")
# Out:
# ROC AUC = 0.9591

# %%
# 10) Plots - one chart per figure (matplotlib default)
mse_test_normal = mse_test[y_test == 1]
plt.figure(figsize=(6,4))
plt.hist(mse_test_normal, bins=50)
plt.title("Reconstruction error — normal (test)")
plt.xlabel("MSE")
plt.ylabel("Count")
plt.show()
