# %%
# ---------------------------------------------------------
# EXPERIMENT 5 - Continuous Bag of Words (CBOW) with Keras
# ---------------------------------------------------------


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Lambda, Input
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import numpy as np
import re, os
from gensim.models import KeyedVectors

# Reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# %%
paragraph = (
    "It is a pleasant day. I love to walk in the park. "
    "The birds are singing and the breeze is cool. "
    "Children are playing games with joy. "
    "Learning new things every day feels rewarding."
)

print(paragraph)
# Out:
# It is a pleasant day. I love to walk in the park. The birds are singing and the breeze is cool. Children are playing games with joy. Learning new things every day feels rewarding.

# %%
# Step 3: Preprocess and tokenize

def simple_clean(text):
    text = text.lower()
    text = re.sub(r"[^a-zA-Z0-9\s\.]", "", text)  # keep letters, numbers, space, dot
    text = re.sub(r"\s+", " ", text).strip()
    return text

# Clean text
cleaned = simple_clean(paragraph)

# Split into sentences
sentences = [s.strip() for s in cleaned.split('.') if s.strip()]
print("Sentences:", sentences)

# Tokenize
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)

word_index = tokenizer.word_index
vocab_size = len(word_index) + 1  # +1 for padding
print("Vocabulary size:", vocab_size)
print("Word index:", word_index)

# Convert sentences to sequences of word IDs
seqs = tokenizer.texts_to_sequences(sentences)
print("Sequences:", seqs)
# Out:
# Sentences: ['it is a pleasant day', 'i love to walk in the park', 'the birds are singing and the breeze is cool', 'children are playing games with joy', 'learning new things every day feels rewarding']
# Vocabulary size: 31
# Word index: {'<OOV>': 1, 'the': 2, 'is': 3, 'day': 4, 'are': 5, 'it': 6, 'a': 7, 'pleasant': 8, 'i': 9, 'love': 10, 'to': 11, 'walk': 12, 'in': 13, 'park': 14, 'birds': 15, 'singing': 16, 'and': 17, 'breeze': 18, 'cool': 19, 'children': 20, 'playing': 21, 'games': 22, 'with': 23, 'joy': 24, 'learning': 25, 'new': 26, 'things': 27, 'every': 28, 'feels': 29, 'rewarding': 30}
# Sequences: [[6, 3, 7, 8, 4], [9, 10, 11, 12, 13, 2, 14], [2, 15, 5, 16, 17, 2, 18, 3, 19], [20, 5, 21, 22, 23, 24], [25, 26, 27, 28, 4, 29, 30]]

# %%
def cbow_training_pairs(seqs, window_size, vocab_size):
    contexts = []
    targets = []
    total_len = 2 * window_size  # left + right context
    
    for text in seqs:
        L = len(text)
        for idx, word in enumerate(text):
            if word == 0:
                continue
            
            start = max(0, idx - window_size)
            end = min(L, idx + window_size + 1)
            
            # Collect context words (exclude target word)
            context = [text[i] for i in range(start, end) if i != idx]
            
            # Pad context
            if len(context) < total_len:
                pad_left = (total_len - len(context)) // 2
                pad_right = total_len - len(context) - pad_left
                context = [0] * pad_left + context + [0] * pad_right
            else:
                context = context[:total_len]
            
            contexts.append(context)
            targets.append(word)
    
    X = np.array(contexts)
    y = to_categorical(np.array(targets), num_classes=vocab_size)
    return X, y

# %%
# Step 5: Build CBOW model

embed_dim = 50
window_size = 2  # <-- ISKO YAHAN ADD KAREIN
context_len = 2 * window_size

model = Sequential([
    Input(shape=(context_len,)),
    Embedding(input_dim=vocab_size, output_dim=embed_dim, name="embedding"),
    Lambda(lambda x: tf.reduce_mean(x, axis=1), name="context_mean"),
    Dense(vocab_size, activation="softmax")
])

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\core.py:216: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 4, 50)               │           1,550 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ context_mean (Lambda)                │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 31)                  │           1,581 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,131 (12.23 KB)
#  Trainable params: 3,131 (12.23 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
window_size = 2
X, y = cbow_training_pairs(seqs, window_size, vocab_size)
print("X shape:", X.shape, "y shape:", y.shape)
# Out:
# X shape: (34, 4) y shape: (34, 31)

# %%
history = model.fit(X, y, epochs=200, batch_size=32, verbose=1)
# Out:
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.0300 - loss: 3.4368
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0901 - loss: 3.4306
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.1097 - loss: 3.4259
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0797 - loss: 3.4215
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0993 - loss: 3.4170
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1293 - loss: 3.4126
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1893 - loss: 3.4082
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.1893 - loss: 3.4038
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1893 - loss: 3.3994
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2194 - loss: 3.3950
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2494 - loss: 3.3905
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2494 - loss: 3.3860
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2194 - loss: 3.3814
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2194 - loss: 3.3768
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2794 - loss: 3.3721
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2794 - loss: 3.3673
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2794 - loss: 3.3625
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2794 - loss: 3.3576
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2794 - loss: 3.3526
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2794 - loss: 3.3475
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2794 - loss: 3.3424
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2794 - loss: 3.3371
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2794 - loss: 3.3317
# Epoch 24/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2794 - loss: 3.3262
# Epoch 25/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3094 - loss: 3.3207
# Epoch 26/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3094 - loss: 3.3150
# Epoch 27/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3395 - loss: 3.3092
# Epoch 28/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3395 - loss: 3.3033
# Epoch 29/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3395 - loss: 3.2972
# Epoch 30/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3395 - loss: 3.2911
# Epoch 31/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3395 - loss: 3.2848
# Epoch 32/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3395 - loss: 3.2784
# Epoch 33/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3395 - loss: 3.2719
# Epoch 34/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3395 - loss: 3.2653
# Epoch 35/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3395 - loss: 3.2585
# Epoch 36/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3395 - loss: 3.2516
# Epoch 37/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3395 - loss: 3.2446
# Epoch 38/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3395 - loss: 3.2375
# Epoch 39/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3395 - loss: 3.2302
# Epoch 40/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3395 - loss: 3.2229
# Epoch 41/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3395 - loss: 3.2154
# Epoch 42/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3395 - loss: 3.2077
# Epoch 43/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3395 - loss: 3.2000
# Epoch 44/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3395 - loss: 3.1921
# Epoch 45/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3395 - loss: 3.1841
# Epoch 46/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3395 - loss: 3.1760
# Epoch 47/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3395 - loss: 3.1678
# Epoch 48/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3395 - loss: 3.1594
# Epoch 49/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3395 - loss: 3.1510
# Epoch 50/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3395 - loss: 3.1424
# Epoch 51/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3695 - loss: 3.1337
# Epoch 52/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3695 - loss: 3.1249
# Epoch 53/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3695 - loss: 3.1160
# Epoch 54/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3695 - loss: 3.1070
# Epoch 55/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3695 - loss: 3.0979
# Epoch 56/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3695 - loss: 3.0887
# Epoch 57/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3695 - loss: 3.0793
# Epoch 58/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3695 - loss: 3.0699
# Epoch 59/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3695 - loss: 3.0604
# Epoch 60/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3695 - loss: 3.0508
# Epoch 61/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3695 - loss: 3.0412
# Epoch 62/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3695 - loss: 3.0314
# Epoch 63/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3695 - loss: 3.0216
# Epoch 64/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3695 - loss: 3.0116
# Epoch 65/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3695 - loss: 3.0016
# Epoch 66/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3695 - loss: 2.9916
# Epoch 67/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3695 - loss: 2.9814
# Epoch 68/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3695 - loss: 2.9712
# Epoch 69/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3695 - loss: 2.9610
# Epoch 70/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3695 - loss: 2.9506
# Epoch 71/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3695 - loss: 2.9402
# Epoch 72/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3695 - loss: 2.9298
# Epoch 73/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3695 - loss: 2.9193
# Epoch 74/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3695 - loss: 2.9088
# Epoch 75/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3695 - loss: 2.8982
# Epoch 76/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3695 - loss: 2.8875
# Epoch 77/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3695 - loss: 2.8768
# Epoch 78/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3695 - loss: 2.8661
# Epoch 79/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3695 - loss: 2.8553
# Epoch 80/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3695 - loss: 2.8445
# Epoch 81/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3695 - loss: 2.8336
# Epoch 82/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3695 - loss: 2.8227
# Epoch 83/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3695 - loss: 2.8118
# Epoch 84/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3695 - loss: 2.8008
# Epoch 85/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3695 - loss: 2.7898
# Epoch 86/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3695 - loss: 2.7787
# Epoch 87/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.3695 - loss: 2.7676
# Epoch 88/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3695 - loss: 2.7564
# Epoch 89/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3695 - loss: 2.7452
# Epoch 90/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3695 - loss: 2.7339
# Epoch 91/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3995 - loss: 2.7226
# Epoch 92/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3995 - loss: 2.7113
# Epoch 93/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3995 - loss: 2.6999
# Epoch 94/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3995 - loss: 2.6884
# Epoch 95/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3995 - loss: 2.6769
# Epoch 96/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3995 - loss: 2.6653
# Epoch 97/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3995 - loss: 2.6537
# Epoch 98/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3995 - loss: 2.6420
# Epoch 99/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3995 - loss: 2.6302
# Epoch 100/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3995 - loss: 2.6184
# Epoch 101/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3995 - loss: 2.6065
# Epoch 102/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3995 - loss: 2.5946
# Epoch 103/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3995 - loss: 2.5826
# Epoch 104/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3995 - loss: 2.5705
# Epoch 105/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3995 - loss: 2.5584
# Epoch 106/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3995 - loss: 2.5462
# Epoch 107/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3995 - loss: 2.5339
# Epoch 108/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3995 - loss: 2.5216
# Epoch 109/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4295 - loss: 2.5092
# Epoch 110/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4295 - loss: 2.4967
# Epoch 111/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4295 - loss: 2.4842
# Epoch 112/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4295 - loss: 2.4716
# Epoch 113/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4295 - loss: 2.4590
# Epoch 114/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4295 - loss: 2.4463
# Epoch 115/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4596 - loss: 2.4335
# Epoch 116/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4596 - loss: 2.4207
# Epoch 117/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4596 - loss: 2.4079
# Epoch 118/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4596 - loss: 2.3950
# Epoch 119/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4596 - loss: 2.3821
# Epoch 120/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4596 - loss: 2.3691
# Epoch 121/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4596 - loss: 2.3560
# Epoch 122/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4596 - loss: 2.3430
# Epoch 123/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4596 - loss: 2.3299
# Epoch 124/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4596 - loss: 2.3168
# Epoch 125/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4596 - loss: 2.3036
# Epoch 126/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4896 - loss: 2.2904
# Epoch 127/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5196 - loss: 2.2772
# Epoch 128/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5196 - loss: 2.2640
# Epoch 129/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5196 - loss: 2.2507
# Epoch 130/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5196 - loss: 2.2375
# Epoch 131/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5196 - loss: 2.2242
# Epoch 132/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5196 - loss: 2.2110
# Epoch 133/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5196 - loss: 2.1977
# Epoch 134/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5196 - loss: 2.1844
# Epoch 135/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5196 - loss: 2.1711
# Epoch 136/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5196 - loss: 2.1579
# Epoch 137/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5196 - loss: 2.1446
# Epoch 138/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5196 - loss: 2.1313
# Epoch 139/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5496 - loss: 2.1181
# Epoch 140/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5496 - loss: 2.1049
# Epoch 141/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5496 - loss: 2.0916
# Epoch 142/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5496 - loss: 2.0785
# Epoch 143/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5496 - loss: 2.0653
# Epoch 144/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5496 - loss: 2.0521
# Epoch 145/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5496 - loss: 2.0390
# Epoch 146/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5496 - loss: 2.0259
# Epoch 147/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5496 - loss: 2.0129
# Epoch 148/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5496 - loss: 1.9999
# Epoch 149/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5496 - loss: 1.9869
# Epoch 150/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5496 - loss: 1.9739
# Epoch 151/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5496 - loss: 1.9610
# Epoch 152/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5496 - loss: 1.9482
# Epoch 153/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5496 - loss: 1.9353
# Epoch 154/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5496 - loss: 1.9225
# Epoch 155/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5496 - loss: 1.9098
# Epoch 156/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5496 - loss: 1.8971
# Epoch 157/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5797 - loss: 1.8845
# Epoch 158/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5797 - loss: 1.8719
# Epoch 159/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5797 - loss: 1.8593
# Epoch 160/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5797 - loss: 1.8468
# Epoch 161/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5797 - loss: 1.8344
# Epoch 162/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5797 - loss: 1.8220
# Epoch 163/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6097 - loss: 1.8097
# Epoch 164/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6097 - loss: 1.7974
# Epoch 165/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6097 - loss: 1.7852
# Epoch 166/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6397 - loss: 1.7731
# Epoch 167/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6397 - loss: 1.7610
# Epoch 168/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6397 - loss: 1.7489
# Epoch 169/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6397 - loss: 1.7369
# Epoch 170/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6397 - loss: 1.7250
# Epoch 171/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6397 - loss: 1.7132
# Epoch 172/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6397 - loss: 1.7014
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6998 - loss: 1.6896
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6998 - loss: 1.6780
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6998 - loss: 1.6664
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6998 - loss: 1.6548
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6998 - loss: 1.6433
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7298 - loss: 1.6319
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7298 - loss: 1.6206
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7298 - loss: 1.6093
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7598 - loss: 1.5981
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7598 - loss: 1.5869
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7598 - loss: 1.5758
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7598 - loss: 1.5648
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7898 - loss: 1.5539
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7898 - loss: 1.5430
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7898 - loss: 1.5321
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8199 - loss: 1.5214
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8199 - loss: 1.5107
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8199 - loss: 1.5001
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8199 - loss: 1.4895
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8199 - loss: 1.4790
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8199 - loss: 1.4686
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8199 - loss: 1.4582
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8199 - loss: 1.4479
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8199 - loss: 1.4377
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8199 - loss: 1.4276
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8199 - loss: 1.4175
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8199 - loss: 1.4074
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8199 - loss: 1.3975

# %%
# Step 7: Save word vectors

weights = model.get_layer("embedding").get_weights()[0]

items = sorted([(w, idx) for w, idx in word_index.items() if idx < weights.shape[0] and idx != 0], key=lambda t: t[1])
num_vectors = len(items)

with open("vectors.txt", "w", encoding="utf-8") as f:
    f.write(f"{num_vectors} {embed_dim}\n")
    for word, idx in items:
        vec = " ".join(map(str, weights[idx].tolist()))
        f.write(f"{word} {vec}\n")

print("vectors.txt saved successfully!")
# Out:
# vectors.txt saved successfully!

# %%
# Step 8: Test with Gensim

cbow_vectors = KeyedVectors.load_word2vec_format("vectors.txt", binary=False)
print("Words in vocab:", cbow_vectors.index_to_key)

for w in ["day", "park", "children", "learning"]:
    if w in cbow_vectors:
        print(f"\nMost similar to '{w}':")
        print(cbow_vectors.most_similar(positive=[w], topn=5))
# Out:
# Words in vocab: ['<OOV>', 'the', 'is', 'day', 'are', 'it', 'a', 'pleasant', 'i', 'love', 'to', 'walk', 'in', 'park', 'birds', 'singing', 'and', 'breeze', 'cool', 'children', 'playing', 'games', 'with', 'joy', 'learning', 'new', 'things', 'every', 'feels', 'rewarding']
#
# Most similar to 'day':
# [('things', 0.9281962513923645), ('new', 0.9247843027114868), ('feels', 0.9192621111869812), ('<OOV>', 0.23396804928779602), ('learning', 0.11979902535676956)]
#
# Most similar to 'park':
# [('walk', 0.7021244764328003), ('birds', 0.46817025542259216), ('to', 0.4376719892024994), ('and', 0.40778347849845886), ('singing', 0.3761458396911621)]
#
# Most similar to 'children':
# [('games', 0.7106499075889587), ('singing', 0.46820130944252014), ('and', 0.4460032880306244), ('with', 0.43175747990608215), ('playing', 0.40719783306121826)]
#
# Most similar to 'learning':
# [('every', 0.7550217509269714), ('rewarding', 0.19442574679851532), ('a', 0.13328316807746887), ('<OOV>', 0.13121579587459564), ('day', 0.11979904770851135)]
